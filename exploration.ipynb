# %%
import pandas as pd
about_player = pd.read_csv('./data/about_players/about_players.csv')
about_player
# Out:
#             Player     # Class Pos Height  Weight           Hometown  \
# 0   D'Mitrik Trice   0.0    SR   G    6-0     184  Huber Heights, OH
# 1     Micah Potter  11.0    SR   F   6-10     248         Mentor, OH
# 2     Brad Davison  34.0    SR   G    6-4     202    Maple Grove, MN
# 3       Aleem Ford   2.0    SR   F    6-8     217  Lawrenceville, GA
# 4     Nate Reuvers  35.0    SR   F   6-11     235      Lakeville, MN
# ..             ...   ...   ...  ..    ...     ...                ...
# 88      Isaac Gard  15.0    JR   G    6-2     165         Oregon, WI
# 89   Camren Hunter   3.0    JR   G    6-3     200         Bryant, AR
# 90  Daniel Freitag   5.0    FR   G    6-2     195    Bloomington, MN
# 91    Chris Hodges  21.0    JR   F    6-9     239     Schaumburg, IL
# 92     Aidan Konop  14.0    FR   G    6-2     195         Sussex, WI
#
#                        High School RSCI Top 100                     Summary  \
# ...

# %%
each_game_player_stats = pd.read_csv('./data/each_game_stats/each_game_stats.csv')
each_game_player_stats
# Out:
#       Gtm        Date                   Opp   Opp.1            Type   Rslt  \
# 0     1.0  2021-11-09  St. Francis Brooklyn    58.0  REG (Non-Conf)      W
# 1     2.0  2021-11-12             Green Bay    34.0  REG (Non-Conf)      W
# 2     3.0  2021-11-15            Providence    63.0  REG (Non-Conf)      L
# 3     4.0  2021-11-22             Texas A&M    58.0  REG (Non-Conf)      W
# 4     5.0  2021-11-23               Houston    63.0  REG (Non-Conf)      W
# ..    ...         ...                   ...     ...             ...    ...
# 205  34.0  2025-03-15        Michigan State    74.0          CTOURN      W
# 206  35.0  2025-03-16              Michigan    59.0          CTOURN      L
# 207  36.0  2025-03-20               Montana    66.0        ROUND-64      W
# 208  37.0  2025-03-22         Brigham Young    91.0        ROUND-32      L
# 209  38.0         NaN                   NaN  2622.0             NaN  27-10
#
# ...

# %%
per_game_player_stats = pd.read_csv('./data/per_game_player_stats/per_game_player_stats.csv')
per_game_player_stats
# Out:
#     Rk           Player  Pos   G  GS     MP    FG   FGA    FG%   3P  ...  \
# 0    1   Chucky Hepburn    G  35  35   32.1   4.3  11.5  0.377  1.9  ...
# 1    2     Steven Crowl    F  35  35   30.6   4.9   9.7  0.510  0.8  ...
# 2    3  Connor Essegian    G  35  19   27.4   3.8   9.4  0.404  2.0  ...
# 3    4       Tyler Wahl    F  32  32   31.5   4.2   9.9  0.423  0.3  ...
# 4    5      Max Klesmit    G  33  33   32.1   2.8   6.5  0.423  1.4  ...
# ..  ..              ...  ...  ..  ..    ...   ...   ...    ...  ...  ...
# 94  12    Isaac Lindsey    G  16   0    3.7   0.3   0.8  0.308  0.1  ...
# 95  13     Chris Hodges    F  11   0    1.9   0.0   0.4  0.000  0.0  ...
# 96  14       Isaac Gard    G   6   0    1.0   0.0   0.2  0.000  0.0  ...
# 97  15     Luke Haertle    G  11   0    1.0   0.0   0.1  0.000  0.0  ...
# 98  16      Team Totals  NaN  36  36  202.1  26.4  57.4  0.461  7.1  ...
#
#      DRB   TRB   AST  STL  BLK  TOV    PF   PTS  Awards  seasonYear
# ...

# %%
per_game_team_stats = pd.read_csv('./data/per_game_team_stats/per_game_team_stats.csv')
per_game_team_stats
# Out:
#    About     G    MP     FG    FGA    FG%     2P    2PA    2P%     3P  ...  \
# 0   Team  35.0  40.9   23.7   57.3   .414   15.9   34.2   .463    7.9  ...
# 1   Rank   NaN   NaN  308th  214th  322nd  333rd  253rd  332nd  118th  ...
# 2   Team  33.0  40.0   24.7   58.5   .422   18.2   37.4   .487    6.5  ...
# 3   Rank   NaN   NaN  248th  137th  279th  164th  143rd  247th  268th  ...
# 4   Team  31.0  40.2   23.5   55.4   .425   14.9   30.8   .483    8.7  ...
# 5   Rank   NaN   NaN  297th  284th  244th  338th  335th  245th   47th  ...
# 6   Team  31.0  40.3   24.7   58.3   .425   16.1   34.5   .466    8.7  ...
# 7   Rank   NaN   NaN  226th  160th  254th  293rd  244th  298th   53rd  ...
# 8   Team  37.0  40.1   26.8   59.0   .454   16.9   30.6   .552    9.9  ...
# 9   Rank   NaN   NaN  122nd  146th  142nd  280th  341st   49th   27th  ...
# 10  Team  36.0  40.4   26.4   57.4   .461   19.3   37.0   .522    7.1  ...
# ...
