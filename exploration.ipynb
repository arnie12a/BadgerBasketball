# %%
import pandas as pd
about_player = pd.read_csv('./data/about_players_2025.csv')
about_player
# Out:
#              Player   # Class Pos Height  Weight             Hometown  \
# 0        John Tonje   9    SR   G    6-5     222            Omaha, NE
# 1    John Blackwell  25    SO   G    6-4     194    Highland Park, MI
# 2      Steven Crowl  22    SR   F    7-0     217            Eagan, MN
# 3      Nolan Winter  31    SO   F   6-11     220        Lakeville, MN
# 4       Max Klesmit  11    SR   G    6-3     180           Neenah, WI
# 5      Kamari McGee   4    SR   G    6-0     180           Racine, WI
# 6    Carter Gilmore   7    SR   F    6-7     215         Hartland, WI
# 7       Xavier Amos  13    JR   F    6-8     210          Chicago, IL
# 8      Jack Janicki  33    FR   G    6-5     190  White Bear Lake, MN
# 9      Markus Ilver  35    SR   F    6-8     219     Tallinn, Estonia
# 10  Riccardo Greppi  18    FR   F   6-10     255         Lecco, Italy
# 11     Jack Robison   2    FR   F    6-5     190        Lakeville, MN
# ...

# %%
each_game_player_stats = pd.read_csv('./data/each_game_stats_2025.csv')
each_game_player_stats
# Out:
#     Gtm        Date                      Opp Opp.1            Type   Rslt  \
# 0     1  2024-11-04               Holy Cross    61  REG (Non-Conf)      W
# 1     2  2024-11-07            Montana State    67  REG (Non-Conf)      W
# 2     3  2024-11-10        Appalachian State    56  REG (Non-Conf)      W
# 3     4  2024-11-15                  Arizona    88  REG (Non-Conf)      W
# 4     5  2024-11-18  Texas–Rio Grande Valley    84  REG (Non-Conf)      W
# 5     6  2024-11-22                      UCF    70  REG (Non-Conf)      W
# 6     7  2024-11-24               Pittsburgh    75  REG (Non-Conf)      W
# 7     8  2024-11-30            Chicago State    53  REG (Non-Conf)      W
# 8     9  2024-12-03                 Michigan    67      REG (Conf)      L
# 9    10  2024-12-07                Marquette    88  REG (Non-Conf)      L
# 10   11  2024-12-10                 Illinois    86      REG (Conf)      L
# 11   12  2024-12-14                   Butler    74  REG (Non-Conf)      W
# ...

# %%
per_game_player_stats = pd.read_csv('./data/per_game_player_stats2025.csv')
per_game_player_stats
# Out:
#       Rk           Player  Pos   G  GS     MP    FG   FGA    FG%   3P  ...  \
# 0    1.0       John Tonje    G  37  37   31.1   5.5  11.9  0.465  2.3  ...
# 1    2.0   John Blackwell    G  37  37   31.2   5.5  12.2  0.451  1.6  ...
# 2    3.0     Steven Crowl    F  37  37   25.6   3.8   7.0  0.539  0.9  ...
# 3    4.0     Nolan Winter    F  37  37   21.1   3.4   6.1  0.564  0.9  ...
# 4    5.0      Max Klesmit    G  33  33   27.6   2.8   8.1  0.345  1.6  ...
# 5    6.0     Kamari McGee    G  37   4   21.9   2.3   5.0  0.457  1.1  ...
# 6    7.0   Carter Gilmore    F  37   0   19.1   1.4   3.0  0.468  0.6  ...
# 7    8.0      Xavier Amos    F  37   0    9.6   1.2   3.3  0.374  0.5  ...
# 8    9.0     Jack Janicki    G  37   0   11.4   0.7   1.9  0.391  0.4  ...
# 9   10.0     Markus Ilver    F  20   0    3.5   0.5   1.4  0.357  0.4  ...
# 10  11.0  Riccardo Greppi    F   9   0    2.3   0.2   0.3  0.667  0.0  ...
# ...

# %%
per_game_team_stats = pd.read_csv('./data/per_game_team_stats_2025.csv')
per_game_team_stats
# Out:
#       About     G    MP     FG    FGA    FG%     2P    2PA   2P%     3P  ...  \
# 0      Team  37.0  40.1   26.8   59.0   .454   16.9   30.6  .552    9.9  ...
# 1      Rank   NaN   NaN  122nd  146th  142nd  280th  341st  49th   27th  ...
# 2  Opponent  37.0  40.1   25.3   60.9   .416   17.4   37.1  .469    7.9  ...
# 3      Rank   NaN   NaN  170th  300th   61st  138th  254th  45th  234th  ...
#
#      FT%    ORB    DRB    TRB    AST    STL    BLK    TOV     PF    PTS
# 0   .826    9.4   27.1   36.5   14.5    5.1    2.4    9.6   16.5   80.1
# 1    1st  273rd   33rd  114th  109th  339th  317th  347th  206th   36th
# 2   .729    9.9   24.1   34.0   12.6    4.8    3.3   10.0   18.5   70.9
# 3  242nd  125th  181st  163rd  256th    3rd  197th   28th  315th  145th
#
# [4 rows x 24 columns]
