# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
dfs = pd.read_html('https://www.sports-reference.com/cbb/schools/wisconsin/men/2021.html')

# %%
len(dfs)
# Out:
# 9

# %%
dfs[7]
# Out:
#       Rk               Player  Pos   G  GS    MP   FG   FGA    FG%   3P  ...  \
# 0    1.0       D'Mitrik Trice    G  31  31  1032  144   351  0.410   62  ...
# 1    2.0         Micah Potter    F  31  20   687  141   280  0.504   39  ...
# 2    3.0         Brad Davison    G  31  31   960   91   264  0.345   63  ...
# 3    4.0           Aleem Ford    F  31  31   818   99   244  0.406   46  ...
# 4    5.0         Nate Reuvers    F  31  24   651  100   238  0.420   18  ...
# 5    6.0         Johnny Davis    G  31   0   753   86   195  0.441   14  ...
# 6    7.0           Tyler Wahl    F  31  18   765   58   133  0.436   10  ...
# 7    8.0      Trevor Anderson    G  29   0   411   33    62  0.532   13  ...
# 8    9.0          Ben Carlson    F   7   0    64    6    11  0.545    1  ...
# 9   10.0         Jordan Davis    G  13   0    19    3     6  0.500    2  ...
# 10  11.0         Steven Crowl    F  12   0    39    4     8  0.500    0  ...
# 11  12.0         Joe Hedstrom    C   9   0    15    1     4  0.250    1  ...
# 12  13.0       Carter Gilmore    F   9   0    17    1     5  0.200    0  ...
# 13  14.0  Carter Higginbottom    G   9   0    10    0     4  0.000    0  ...
# 14  15.0       Justin Taphorn    G   6   0     8    0     1  0.000    0  ...
# 15  16.0         Walt McGrory    G   1   0     1    0     0    NaN    0  ...
# 16   NaN          Team Totals  NaN  31  31  6250  767  1806  0.425  269  ...
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Awards
# 0     3  102  105  123   26    1   56   51   430     NaN
# 1    56  128  184   42   16   23   42   63   389     NaN
# 2    10   99  109   73   33    0   27   72   311     NaN
# 3    26  105  131   34   19   16   29   63   269     NaN
# 4    30   71  101   22    8   40   31   67   257     NaN
# 5    34   94  128   35   34   18   34   66   218     NaN
# 6    33  100  133   42   31   21   28   68   160     NaN
# 7     8   33   41   36    6    0   13   23    91     NaN
# 8     1    5    6    4    1    3    1   10    20     NaN
# 9     0    1    1    0    0    0    1    0     8     NaN
# 10    4    5    9    2    0    1    3    9     8     NaN
# 11    2    1    3    0    0    0    0    4     4     NaN
# 12    0    3    3    0    0    0    0    2     2     NaN
# 13    0    0    0    1    1    0    2    1     0     NaN
# 14    0    0    0    0    0    0    1    0     0     NaN
# 15    0    0    0    0    0    0    0    1     0     NaN
# 16  207  747  954  414  175  123  280  500  2167     NaN
#
# [17 rows x 29 columns]

# %%
def getURL(year):
    import pandas as pd
    dfs = pd.read_html(f'https://www.sports-reference.com/cbb/schools/wisconsin/men/{year}.html')
    total_df = dfs[7]
    return total_df
